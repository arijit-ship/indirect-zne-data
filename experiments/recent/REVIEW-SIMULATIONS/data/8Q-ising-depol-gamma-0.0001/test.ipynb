# %% [markdown]
# # 🔍 Experiment Validation
#
# This notebook scans all experiment folders, checks each JSON file for `artifacts.opt_obj.success`, and reports:
#
# - ✅ Successful optimizations
# - ❌ Failed optimizations
# - ⚠️ Missing keys
# - 💥 Invalid or unreadable JSON files
#
# A summary of the total, passed, and failed files is displayed at the end.

# %%
from pathlib import Path
import json

# Root directory (the folder containing this notebook)
root = Path.cwd()
print("🚀 Scanning experiment folders...\n")

total = 0
passed = 0
failed = 0

vqe_subfolders = ["VQE", "VQE_noiseoff"]

for vqe_name in vqe_subfolders:
    vqe_folder = root / vqe_name
    if not vqe_folder.is_dir():
        print(f"⚠️ no {vqe_name} subfolder found, skipping")
        continue

    print(f"📂 {vqe_name}")
    for json_file in sorted(vqe_folder.glob("*.json")):
        total += 1
        try:
            with open(json_file, "r") as f:
                data = json.load(f)
            success = data["artifacts"]["opt_obj"]["success"]
            if success:
                passed += 1
                print(f"   ✅ {json_file.name}")
            else:
                failed += 1
                print(f"   ❌ {json_file.name}  →  optimization failed")
        except KeyError as e:
            failed += 1
            print(f"   ⚠️  {json_file.name}  →  Missing key: {e}")
        except Exception as e:
            failed += 1
            print(f"   💥 {json_file.name}  →  {type(e).__name__}: {e}")
    print()  # blank line between folders

print("─" * 60)
print("📊 Scan Complete")
print(f"📄 Total JSONs : {total}")
print(f"✅ Passed      : {passed}")
print(f"❌ Failed      : {failed}")

if failed == 0:
    print("\n🎉 All optimization runs completed successfully!")
else:
    print(f"\n🚨 {failed} file(s) require attention.")
# Out:
# 🚀 Scanning experiment folders...
#
# 📂 VQE
#    ✅ 8Q-t20-ising-depol_run000_efcbf307-91d0-41b6-8fa0-c68047ed8743_VQE.json
#    ✅ 8Q-t20-ising-depol_run001_357bcefe-81f5-4d24-8f75-d2df57674835_VQE.json
#    ✅ 8Q-t20-ising-depol_run002_e190a346-8072-4214-9026-b98af0475500_VQE.json
#    ✅ 8Q-t20-ising-depol_run003_87e38941-148e-4225-bf38-d7376bb9c3e7_VQE.json
#    ✅ 8Q-t20-ising-depol_run004_93008ce2-62a5-4ad7-a456-e39d719d9508_VQE.json
#    ✅ 8Q-t20-ising-depol_run005_3a1b8485-4e76-4fbf-be4d-a06b1a6967ff_VQE.json
#    ✅ 8Q-t20-ising-depol_run006_cc748647-1152-4e7c-93b9-415dd9baa424_VQE.json
#    ✅ 8Q-t20-ising-depol_run007_1a08004f-167e-4814-9bfa-dc52560c144b_VQE.json
#    ✅ 8Q-t20-ising-depol_run008_a748fefe-b14c-420a-8430-643e4113e3d2_VQE.json
#    ✅ 8Q-t20-ising-depol_run009_4f43e1ad-95fb-4954-8407-25922a63f20d_VQE.json
#
# ⚠️ no VQE_noiseoff subfolder found, skipping
# ────────────────────────────────────────────────────────────
# 📊 Scan Complete
# 📄 Total JSONs : 10
# ✅ Passed      : 10
# ❌ Failed      : 0
#
# 🎉 All optimization runs completed successfully!
