# %% [markdown]
# # 🔍 Experiment Validation
#
# This notebook scans all experiment folders, checks each JSON file for `artifacts.opt_obj.success`, and reports:
#
# - ✅ Successful optimizations
# - ❌ Failed optimizations
# - ⚠️ Missing keys
# - 💥 Invalid or unreadable JSON files
#
# A summary of the total, passed, and failed files is displayed at the end.

# %%
from pathlib import Path
import json

# Root directory (the folder containing this notebook)
root = Path.cwd()
print("🚀 Scanning experiment folders...\n")

total = 0
passed = 0
failed = 0

vqe_subfolders = ["VQE", "VQE_noiseoff"]

for vqe_name in vqe_subfolders:
    vqe_folder = root / vqe_name
    if not vqe_folder.is_dir():
        print(f"⚠️ no {vqe_name} subfolder found, skipping")
        continue

    print(f"📂 {vqe_name}")
    for json_file in sorted(vqe_folder.glob("*.json")):
        total += 1
        try:
            with open(json_file, "r") as f:
                data = json.load(f)
            success = data["artifacts"]["opt_obj"]["success"]
            if success:
                passed += 1
                print(f"   ✅ {json_file.name}")
            else:
                failed += 1
                print(f"   ❌ {json_file.name}  →  optimization failed")
        except KeyError as e:
            failed += 1
            print(f"   ⚠️  {json_file.name}  →  Missing key: {e}")
        except Exception as e:
            failed += 1
            print(f"   💥 {json_file.name}  →  {type(e).__name__}: {e}")
    print()  # blank line between folders

print("─" * 60)
print("📊 Scan Complete")
print(f"📄 Total JSONs : {total}")
print(f"✅ Passed      : {passed}")
print(f"❌ Failed      : {failed}")

if failed == 0:
    print("\n🎉 All optimization runs completed successfully!")
else:
    print(f"\n🚨 {failed} file(s) require attention.")
# Out:
# 🚀 Scanning experiment folders...
#
# 📂 VQE
#    ✅ 8Q-t20-ising-depol_run000_caebd250-1469-4069-b249-c7cc57d7e92b_VQE.json
#    ✅ 8Q-t20-ising-depol_run001_87ec3972-818a-49e0-bcc3-b02d10ba0dc4_VQE.json
#    ✅ 8Q-t20-ising-depol_run002_0dd191bd-03d4-4d74-9e92-885a309bf1f3_VQE.json
#    ✅ 8Q-t20-ising-depol_run003_e82fb316-c79e-4f32-bceb-226b0ab351ce_VQE.json
#    ✅ 8Q-t20-ising-depol_run004_78a92671-a2f2-44e9-b212-df28f0604432_VQE.json
#    ✅ 8Q-t20-ising-depol_run005_35346ae4-c4c5-417d-b0e4-21b9f23ccfc0_VQE.json
#    ✅ 8Q-t20-ising-depol_run006_b0eadbe5-b2ca-45d3-8b54-50c928832089_VQE.json
#    ✅ 8Q-t20-ising-depol_run007_37877deb-1741-4246-9e09-f2f9ed76487d_VQE.json
#    ✅ 8Q-t20-ising-depol_run008_2d413be9-1664-4a49-9198-171215ecdb55_VQE.json
#    ✅ 8Q-t20-ising-depol_run009_48c00314-d5e9-4fde-a012-2a2fdce66522_VQE.json
#
# 📂 VQE_noiseoff
#    ✅ 8Q-t20-ising-noise_off_run000_02045be6-b1c3-4b0d-8ad1-03bb3cf080b3_VQE.json
#    ✅ 8Q-t20-ising-noise_off_run001_6885c900-05d4-4dfe-80fc-38e96ea3281d_VQE.json
#    ✅ 8Q-t20-ising-noise_off_run002_156e38c1-2737-43ab-b335-546357f28d1c_VQE.json
#    ✅ 8Q-t20-ising-noise_off_run003_5a26b7f2-5f65-4662-989d-3e5b566177e8_VQE.json
#    ✅ 8Q-t20-ising-noise_off_run004_c230a01b-902b-4545-87cb-f031f39b33e6_VQE.json
#    ✅ 8Q-t20-ising-noise_off_run005_0f9f9f5a-982d-40eb-8932-63e03f7cb7ac_VQE.json
#    ✅ 8Q-t20-ising-noise_off_run006_208fec64-9a44-4d3f-b7f0-63fb4192ca53_VQE.json
#    ✅ 8Q-t20-ising-noise_off_run007_395e52ef-a5de-4bbe-afcc-1ef1e442aa17_VQE.json
#    ✅ 8Q-t20-ising-noise_off_run008_3a61d658-6e47-4103-9d82-cc8cb713675a_VQE.json
#    ✅ 8Q-t20-ising-noise_off_run009_770c83ac-b025-43a0-b254-fb53d5384266_VQE.json
#
# ────────────────────────────────────────────────────────────
# 📊 Scan Complete
# 📄 Total JSONs : 20
# ✅ Passed      : 20
# ❌ Failed      : 0
#
# 🎉 All optimization runs completed successfully!
