# %% [markdown]
# # 🔍 Experiment Validation
#
# This notebook scans all experiment folders, checks each JSON file for `artifacts.opt_obj.success`, and reports:
#
# - ✅ Successful optimizations
# - ❌ Failed optimizations
# - ⚠️ Missing keys
# - 💥 Invalid or unreadable JSON files
#
# A summary of the total, passed, and failed files is displayed at the end.

# %%
from pathlib import Path
import json

# Root directory (the folder containing this notebook)
root = Path.cwd()
print("🚀 Scanning experiment folders...\n")

total = 0
passed = 0
failed = 0

vqe_subfolders = ["VQE", "VQE_noiseoff"]

for vqe_name in vqe_subfolders:
    vqe_folder = root / vqe_name
    if not vqe_folder.is_dir():
        print(f"⚠️ no {vqe_name} subfolder found, skipping")
        continue

    print(f"📂 {vqe_name}")
    for json_file in sorted(vqe_folder.glob("*.json")):
        total += 1
        try:
            with open(json_file, "r") as f:
                data = json.load(f)
            success = data["artifacts"]["opt_obj"]["success"]
            if success:
                passed += 1
                print(f"   ✅ {json_file.name}")
            else:
                failed += 1
                print(f"   ❌ {json_file.name}  →  optimization failed")
        except KeyError as e:
            failed += 1
            print(f"   ⚠️  {json_file.name}  →  Missing key: {e}")
        except Exception as e:
            failed += 1
            print(f"   💥 {json_file.name}  →  {type(e).__name__}: {e}")
    print()  # blank line between folders

print("─" * 60)
print("📊 Scan Complete")
print(f"📄 Total JSONs : {total}")
print(f"✅ Passed      : {passed}")
print(f"❌ Failed      : {failed}")

if failed == 0:
    print("\n🎉 All optimization runs completed successfully!")
else:
    print(f"\n🚨 {failed} file(s) require attention.")
# Out:
# 🚀 Scanning experiment folders...
#
# 📂 VQE
#    ✅ 8Q-t20-heisen-amp_run000_47d3731f-9f4e-4f5a-ad28-39ecc8c23e61_VQE.json
#    ✅ 8Q-t20-heisen-amp_run001_0389087b-7e88-4a69-bd61-06a443e6a01d_VQE.json
#    ✅ 8Q-t20-heisen-amp_run002_83fdeb1e-d95a-4ee4-a0d8-eb38175d5e3b_VQE.json
#    ✅ 8Q-t20-heisen-amp_run003_4f87942b-2ef8-47ab-9f10-76c7c8f5d6d7_VQE.json
#    ✅ 8Q-t20-heisen-amp_run004_edf527ba-ae10-4988-a7db-f19a925adf00_VQE.json
#    ✅ 8Q-t20-heisen-amp_run005_bfd9fe01-e4f1-4c75-83dd-bc9ee80f6956_VQE.json
#    ✅ 8Q-t20-heisen-amp_run006_3cb45fb9-16d7-4ac9-9e16-4450eb5f02a0_VQE.json
#    ✅ 8Q-t20-heisen-amp_run007_060c810b-fb51-4359-8f1b-1cabb7a24714_VQE.json
#    ✅ 8Q-t20-heisen-amp_run008_2fcde7b6-bee3-4181-815d-79de7e2bd07c_VQE.json
#    ✅ 8Q-t20-heisen-amp_run009_6db53149-50db-48bb-9d88-92c16cff0090_VQE.json
#
# 📂 VQE_noiseoff
#    ✅ 8Q-t20-heisen-noise-off_run000_6e1a405b-121a-400d-8df5-4ac57f3215ed_VQE.json
#    ✅ 8Q-t20-heisen-noise-off_run001_ac80866f-8c8b-45f1-946d-62610223ba7b_VQE.json
#    ✅ 8Q-t20-heisen-noise-off_run002_4e16f8ea-9d71-488e-8ee7-9df142ff7fda_VQE.json
#    ✅ 8Q-t20-heisen-noise-off_run003_ae810032-00d9-49a9-aebb-149fde5b1854_VQE.json
#    ✅ 8Q-t20-heisen-noise-off_run004_89ec995f-c3cc-4d69-bc5c-58607c3514a8_VQE.json
#    ✅ 8Q-t20-heisen-noise-off_run005_d41ea3ce-7273-406e-85e1-2908d9fab534_VQE.json
#    ✅ 8Q-t20-heisen-noise-off_run006_2b554077-d11b-48f1-bb3a-446525c80ddb_VQE.json
#    ✅ 8Q-t20-heisen-noise-off_run007_21cf04c1-456b-403a-bf0d-fba219309848_VQE.json
#    ✅ 8Q-t20-heisen-noise-off_run008_bcf9add1-ee57-426c-8961-7c3a17154f7b_VQE.json
#    ✅ 8Q-t20-heisen-noise-off_run009_e8f067b4-ceee-4fd7-9e35-4a2bc9527ea3_VQE.json
#
# ────────────────────────────────────────────────────────────
# 📊 Scan Complete
# 📄 Total JSONs : 20
# ✅ Passed      : 20
# ❌ Failed      : 0
#
# 🎉 All optimization runs completed successfully!
