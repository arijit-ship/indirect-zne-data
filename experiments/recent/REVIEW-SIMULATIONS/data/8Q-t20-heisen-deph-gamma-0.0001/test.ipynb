# %% [markdown]
# # 🔍 Experiment Validation
#
# This notebook scans all experiment folders, checks each JSON file for `artifacts.opt_obj.success`, and reports:
#
# - ✅ Successful optimizations
# - ❌ Failed optimizations
# - ⚠️ Missing keys
# - 💥 Invalid or unreadable JSON files
#
# A summary of the total, passed, and failed files is displayed at the end.

# %%
from pathlib import Path
import json

# Root directory (the folder containing this notebook)
root = Path.cwd()
print("🚀 Scanning experiment folders...\n")

total = 0
passed = 0
failed = 0

vqe_subfolders = ["VQE", "VQE_noiseoff"]

for vqe_name in vqe_subfolders:
    vqe_folder = root / vqe_name
    if not vqe_folder.is_dir():
        print(f"⚠️ no {vqe_name} subfolder found, skipping")
        continue

    print(f"📂 {vqe_name}")
    for json_file in sorted(vqe_folder.glob("*.json")):
        total += 1
        try:
            with open(json_file, "r") as f:
                data = json.load(f)
            success = data["artifacts"]["opt_obj"]["success"]
            if success:
                passed += 1
                print(f"   ✅ {json_file.name}")
            else:
                failed += 1
                print(f"   ❌ {json_file.name}  →  optimization failed")
        except KeyError as e:
            failed += 1
            print(f"   ⚠️  {json_file.name}  →  Missing key: {e}")
        except Exception as e:
            failed += 1
            print(f"   💥 {json_file.name}  →  {type(e).__name__}: {e}")
    print()  # blank line between folders

print("─" * 60)
print("📊 Scan Complete")
print(f"📄 Total JSONs : {total}")
print(f"✅ Passed      : {passed}")
print(f"❌ Failed      : {failed}")

if failed == 0:
    print("\n🎉 All optimization runs completed successfully!")
else:
    print(f"\n🚨 {failed} file(s) require attention.")
# Out:
# 🚀 Scanning experiment folders...
#
# 📂 VQE
#    ✅ 8Q-t20-heisen-dephasing_run000_6681a144-8493-4062-951e-361d0767194e_VQE.json
#    ✅ 8Q-t20-heisen-dephasing_run001_856d76a7-d87b-42d9-aa7e-5a8f774a293e_VQE.json
#    ✅ 8Q-t20-heisen-dephasing_run002_30b05995-0bc5-4dbf-9477-d48a80ea7bc7_VQE.json
#    ✅ 8Q-t20-heisen-dephasing_run003_b9484588-b2ab-401b-9dc2-e9c2f0d73533_VQE.json
#    ✅ 8Q-t20-heisen-dephasing_run004_1132ada1-781d-4477-ad3b-c609ca39a936_VQE.json
#    ✅ 8Q-t20-heisen-dephasing_run005_c935de63-c858-4809-a31c-27ab481bc1b4_VQE.json
#    ✅ 8Q-t20-heisen-dephasing_run006_ed746d98-5064-40d1-a1fb-48d6101ae6e6_VQE.json
#    ✅ 8Q-t20-heisen-dephasing_run007_d9f5f906-a4ed-4273-8b1e-1f41f9b8ad2e_VQE.json
#    ✅ 8Q-t20-heisen-dephasing_run008_76e49981-e88a-4cb5-9bbe-b962c1da5bd8_VQE.json
#    ✅ 8Q-t20-heisen-dephasing_run009_5e561b0a-f36f-4e87-8ae3-67966e7a2498_VQE.json
#
# ⚠️ no VQE_noiseoff subfolder found, skipping
# ────────────────────────────────────────────────────────────
# 📊 Scan Complete
# 📄 Total JSONs : 10
# ✅ Passed      : 10
# ❌ Failed      : 0
#
# 🎉 All optimization runs completed successfully!
